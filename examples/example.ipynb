# %%
# %pip install eule==1.0.8
# Out:
# ...
#   Attempting uninstall: eule
#     Found existing installation: eule 1.0.7
#     Uninstalling eule-1.0.7:
#       Successfully uninstalled eule-1.0.7
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade eule

# %%
# %pip list
# Out:
# Package                       Version
# ----------------------------- -----------
# alabaster                     0.7.12
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# asttokens                     2.0.5
# asv                           0.6.1
# asv-runner                    0.1.0
# attrs                         21.4.0
# Babel                         2.10.1
# backcall                      0.2.0
# beautifulsoup4                4.11.1
# beniget                       0.4.1
# bleach                        5.0.1
# certifi                       2022.5.18.1
# cffi                          1.15.1
# cftime                        1.6.1
# charset-normalizer            2.0.12
# click                         8.1.3
# cloudpickle                   2.1.0
# commonmark                    0.9.1
# contourpy                     1.0.6
# cycler                        0.11.0
# Cython                        0.29.35
# ...

# %%
from eule import euler
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 from eule import euler
#
# ImportError: cannot import name 'euler' from 'eule' (/home/brunolnetto/github/scipy/myenv/lib/python3.8/site-packages/eule/__init__.py)

# %%
from eule.core import euler

set = {'a': [1, 2, 3], 'b': [2, 3, 4], 'c': [3, 4, 5], 'd': [3, 5, 6]}

diagram = euler(set)

# Euler dictionary:
# {
#     ('a', 'b'): [2], 
#     ('b', 'c'): [4], 
#     ('a', 'b', 'c', 'd'): [3], 
#     ('d',): [6], 
#     ('c', 'd'): [5], 
#     ('a',): [1]
# }
print(diagram)
# Out:
# {('d',): [6], ('c', 'd'): [5], ('a', 'b', 'c', 'd'): [3], ('a', 'b'): [2], ('b', 'c'): [4], ('a',): [1]}

# %%
results = []
for num_sets, set_size in test_cases:
    print(num_sets, set_size)
# Out:
# 10 1000
# 50 1000
# 10 10000
# 50 10000
# 100 10000

# %%
import time
import signal
from memory_profiler import memory_usage
import matplotlib.pyplot as plt
import numpy as np

from eule.core import euler

class TimeoutException(Exception):
    pass

def handler(signum, frame):
    """Signal handler for time limits."""
    raise TimeoutException("Execution exceeded time limit")

def create_sets(num_sets, set_size):
    """Create synthetic sets based on provided key and value cardinalities."""
    return {f'set_{i}': list(range(i * set_size, (i + 1) * set_size)) for i in range(num_sets)}

def performance_test(num_sets, set_size, time_limit=10, memory_limit=500):
    """Runs a performance test with specific set cardinalities, time, and memory limits."""
    
    sets = create_sets(num_sets, set_size)
    signal.signal(signal.SIGALRM, handler)
    signal.alarm(time_limit)

    try:
        # Measure execution time and memory usage
        start_time = time.time()
        mem_usage = memory_usage((euler, (sets,)), interval=0.1)
        exec_time = time.time() - start_time
        max_memory = max(mem_usage) - min(mem_usage)

        if max_memory > memory_limit:
            raise MemoryError(f"Exceeded memory limit of {memory_limit} MB")

        signal.alarm(0)
        return exec_time, max_memory

    except TimeoutException:
        print(f"Timeout: Execution took longer than {time_limit} seconds")
        return None, None
    except MemoryError:
        print(f"MemoryError: Exceeded memory limit of {memory_limit} MB")
        return None, None

# Define test cases
test_cases = [
    (10, 1000),
    (50, 1000),
    (10, 10000),
    (50, 10000),
    (100, 10000)
]

# %%
performance_test(2, 10, time_limit=600, memory_limit=500000)
# Out:
# (0.1797771453857422, 0.0)

# %%
sets_={
    k: set(v)
    for k, v in create_sets(2, 10000000).items()
}

els_0_1=sets_['set_0'].intersection(sets_['set_1'])
els_0=sets_['set_0'].difference(els_0_1)
els_1=sets_['set_1'].difference(els_0_1)
