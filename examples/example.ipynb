# %%
# %pip install eule
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached eule-0.3.4-py3-none-any.whl (5.7 kB)
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade eule

# %%
# %pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# acme                          1.27.0
# alabaster                     0.7.12
# alembic                       1.8.0
# appdirs                       1.4.4
# apturl                        0.5.2
# argh                          0.26.2
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# astroid                       2.3.3
# asttokens                     2.0.5
# async-generator               1.10
# attrs                         21.4.0
# Babel                         2.11.0
# backcall                      0.2.0
# bcrypt                        3.2.2
# beautifulsoup4                4.11.1
# black                         22.3.0
# bleach                        5.0.0
# blinker                       1.4
# Brlapi                        0.7.0
# build                         0.9.0
# bump2version                  0.5.11
# certbot                       1.27.0
# ...

# %%
import eule

# %%
#!/usr/bin/env python
import eule

set = {'a': [1, 2, 3], 'b': [2, 3, 4], 'c': [3, 4, 5], 'd': [3, 5, 6]}

diagram = eule.euler(set)

# Euler dictionary:
# {
#     ('a', 'b'): [2], 
#     ('b', 'c'): [4], 
#     ('a', 'b', 'c', 'd'): [3], 
#     ('d',): [6], 
#     ('c', 'd'): [5], 
#     ('a',): [1]
# }
print(diagram)
# Out:
# {('a', 'b'): [2], ('b', 'c'): [4], ('a', 'b', 'c', 'd'): [3], ('d',): [6], ('c', 'd'): [5], ('a',): [1]}
