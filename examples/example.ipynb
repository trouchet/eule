# %%
#!/usr/bin/env python
import eule

set = {'a': [1, 2, 3], 'b': [2, 3, 4], 'c': [3, 4, 5], 'd': [3, 5, 6]}

diagram = eule.spread_euler(set)

# Euler dictionary:
#   {
#       'a,b': [2],
#       'b,c': [4],
#       'a,b,c,d': [3],
#       'c,d': [5],
#       'd': [6],
#       'a': [1]
#   }
print(diagram)
# Out:
# {'c,d': [5], 'b,c': [4], 'a,b,c,d': [3], 'a,b': [2], 'd': [6], 'a': [1]}
